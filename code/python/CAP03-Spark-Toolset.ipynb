# %% [markdown]
# # Chapter 3 - A Tour of Spark's Toolset
#
# This chapter presents a whirlwind tour of much of what Spark has to offer, including some of the APIs we have not yet convered and a few of the main libraries.

# %% [markdown]
# ## Structured Streaming

# %%
files_path = "/Workspace/Repos/romulo.leonardo@gmail.com/Spark-Guide"

staticDataFrame = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load(f"{files_path}/datasets/retail-data/by-day/*.csv")

staticDataFrame.createOrReplaceTempView("retail_data")
staticSchema = staticDataFrame.schema

display(staticDataFrame)
display(staticSchema)

# %%
from pyspark.sql.functions import window, column, desc, col

staticDataFrame \
    .selectExpr(
        "CustomerId",
        "(UnitPrice * Quantity) as total_cost",
        "InvoiceDate") \
    .groupBy(col("CustomerId"), window(col("InvoiceDate"), "1 day")) \
    .sum("total_cost") \
    .show(5)

# %%
spark.conf.set("spark.sql.shuffle.partitions", "5")

streamingDataFrame = spark.readStream \
    .schema(staticSchema) \
    .option("maxFilesPerTrigger", 1) \
    .format("csv") \
    .option("header", "true") \
    .load(f"{files_path}/datasets/retail-data/by-day/*.csv")

streamingDataFrame.isStreaming

# %%
purchaseByCustomerPerHour = streamingDataFrame \
    .selectExpr(
        "CustomerId",
        "(UnitPrice * Quantity) as total_cost",
        "InvoiceDate") \
    .groupBy(col("CustomerId"), window(col("InvoiceDate"), "1 day")) \
    .sum("total_cost")

# %%
purchaseByCustomerPerHour.writeStream \
    .format("memory") \
    .queryName("customer_purchases") \
    .outputMode("complete") \
    .trigger(availableNow=True) \
    .option("checkpointLocation", f"{files_path}/datasets/checkpoint/customer_purchases") \
    .start()

# %%
spark.sql("""
    SELECT *
    FROM customer_purchases
    ORDER BY 'sum(total_cost)' DESC
""").show(5)

# %% [markdown]
# ## Machine Learning with K-Means

# %%
staticDataFrame.printSchema()

# %%
from pyspark.sql.functions import date_format, col

preppedDataFrame = staticDataFrame \
    .na.fill(0) \
    .withColumn("day_of_week", date_format(col("InvoiceDate"), "EEEE")) \
    .coalesce(5)

# %%
trainDataFrame = preppedDataFrame.where("InvoiceDate < '2011-02-01'")
testDataFrame = preppedDataFrame.where("InvoiceDate >= '2011-02-01'")

trainDataFrame.count()
testDataFrame.count()

# %%
from pyspark.ml.feature import StringIndexer

indexer = StringIndexer() \
    .setInputCol("day_of_week") \
    .setOutputCol("day_of_week_index")

# %%
from pyspark.ml.feature import OneHotEncoder

encoder = OneHotEncoder() \
    .setInputCol("day_of_week_index") \
    .setOutputCol("day_of_week_encoded")

# %%
from pyspark.ml.feature import VectorAssembler

vectorAssembler = VectorAssembler() \
    .setInputCols(["UnitPrice", "Quantity", "day_of_week_encoded"]) \
    .setOutputCol("features")

# %%
from pyspark.ml import Pipeline

transformatPipeline = Pipeline().setStages([indexer, encoder, vectorAssembler])

fittedPipeline = transformatPipeline.fit(trainDataFrame)

transformedTraining = fittedPipeline.transform(trainDataFrame)

#transformedTraining.cache()

# %%
from pyspark.ml.clustering import KMeans

kmeans = KMeans().setK(20).setSeed(1)

kmModel = kmeans.fit(transformedTraining)

kmModel.computeCost(transformedTraining)

# %%
transformedTest = fittedPipeline.transform(testDataFrame)

kmModel.computeCost(transformedTest)

# %% [markdown]
# # End
