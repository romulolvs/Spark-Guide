# %% [markdown]
# # Chapter 2 - A Gentle Introduction to Spark
#
# This chapter presents a gentle introduction to spark, in which we will walk through the core architecture of a cluster, Spark Application, and Spark's structured APIs using DataFrames and SQL

# %% [markdown]
# ## The Spark Session

# %%
# Simples task to create a range of numbers
myRange = spark.range(1000).toDF("number")

# %% [markdown]
# ## Transformations

# %%
# Simple transformation to find all even numbers in DataFrame
divisBy2 = myRange.where("number % 2 = 0")
divisBy2.display()

# %% [markdown]
# ## Actions

# %%
# The total numbers of records in the DataFrame
divisBy2.count()

# %% [markdown]
# ## An End-to-End Example
#
# Using Spark to analyze some flight data from United States Bureau of Transportation statistics

# %%
files_path = "/Workspace/Repos/romulo.leonardo@gmail.com/Spark-Guide"

flightData2015 = spark.read \
                      .option("inferSchema", "true") \
                      .option("header", "true")\
                      .csv(f"{files_path}/datasets/flight-data/csv/2015-summary.csv")

flightData2015.display()

# %%
flightData2015.sort("count").explain()

# %%
spark.conf.set("spark.sql.shuffle.partitions", "5")

flightData2015.sort("count").take(2)

# %% [markdown]
# ## DataFrames and Spark SQL

# %%
flightData2015.createOrReplaceTempView("flight_data_2015")

sqlWay = spark.sql("""
    SELECT dest_country_name, count(1) AS qtde
    FROM flight_data_2015
    GROUP BY dest_country_name
""")

DataFrameWay = flightData2015.groupBy("dest_country_name").count()

sqlWay.explain()
DataFrameWay.explain()

# %%
spark.sql("SELECT MAX(count) AS maxCount FROM flight_data_2015").display()

# %%
from pyspark.sql.functions import max

flightData2015.select(max("count").alias("maxCount")).display()

# %%
maxSql = spark.sql("""
    SELECT dest_country_name, SUM(count) AS destination_total
    FROM flight_data_2015
    GROUP BY dest_country_name
    ORDER BY destination_total DESC
    LIMIT 5
""")

maxSql.show()

# %%
from pyspark.sql.functions import desc

flightData2015\
    .groupBy("dest_country_name")\
    .sum("count")\
    .withColumnRenamed("sum(count)", "destination_total")\
    .sort(desc("destination_total"))\
    .limit(5)\
    .show()

# %%
flightData2015\
    .groupBy("dest_country_name")\
    .sum("count")\
    .withColumnRenamed("sum(count)", "destination_total")\
    .sort(desc("destination_total"))\
    .limit(5)\
    .explain()

# %% [markdown]
# # End
